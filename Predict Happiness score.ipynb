# %% [markdown]
# # Predict Happpiness Score

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
from PIL import Image
import matplotlib.pyplot as plt  # For displaying the image using matplotlib

# Define the image file path using a raw string (prefix with 'r')
image_path = "C:/Users/ssour/Downloads/close-up-of-happy-smile-icon-7f1rlnzpaj3dpof3.jpg"

# Open an image file
img = Image.open(image_path)

# Display the image using matplotlib
plt.imshow(img)
plt.axis('off')  # Turn off axes for image display
plt.show()

# %% [markdown]
# # Importing Datasets

# %%
df=pd.read_csv("C:/Users/ssour/Downloads/happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [raw]
# Happiness score datasets typically refer to collections of data that measure and quantify levels of happiness or subjective well-being across different populations or countries. These datasets are constructed based on surveys and assessments that ask individuals to evaluate and report on their own happiness or life satisfaction. Here's how happiness score datasets are commonly defined:
#
# Happiness Score: This is a numerical value assigned to each country or individual based on survey responses or other indicators of well-being. The score is often derived from questions that ask individuals to rate their life satisfaction or happiness on a scale.
# Components: Happiness score datasets usually include multiple components or variables that contribute to the overall happiness score. These components might include economic factors (like GDP per capita), social factors (like social support networks), health indicators, perceptions of freedom, generosity, and levels of corruption.
#
# Data Sources: The datasets are compiled from various sources such as national statistical agencies, international organizations (like the United Nations or World Bank), and research institutions that conduct large-scale surveys on well-being.
#
# Survey Instruments: The primary method for collecting happiness data is through surveys that ask respondents to rate their happiness or life satisfaction. Common survey instruments include the World Happiness Report's Cantril ladder, which asks individuals to rate their life satisfaction on a scale from 0 to 10.
#
# Country-Level Analysis: Happiness score datasets are often organized by country, allowing for cross-country comparisons and analysis. This enables researchers and policymakers to identify patterns and factors influencing happiness levels across different nations.
# Temporal Trends: Many happiness score datasets include longitudinal data, showing changes in happiness scores over time. This allows for the analysis of trends and the impact of social, economic, or policy changes on subjective well-being.
#
#
# Purpose: These datasets are used for various purposes, including academic research, policy-making, and public awareness campaigns. They provide valuable insights into the determinants of happiness and can inform strategies for improving well-being at both individual and societal levels.
# Some well-known happiness score datasets include the World Happiness Report, the Gallup World Poll, and various national surveys conducted by governments and academic institutions. These datasets play a crucial role in understanding and promoting well-being and quality of life around the world.

# %%
# Here we can see all columns 
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# Now see top 10 data in these datasets
df.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
# Now see last 5 data in these datasets
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Here we can see the shape of these datasets
df.shape
# Out:
# (158, 12)

# %% [raw]
# Here we can clear see that in happiness datasets there are 158 rows and 12 columns .In 12 columns one of the columns is my target variable which is my 'Happiness Score' Columns.

# %%
print("The Dimension of these datasets: ",df.shape)
print("The alll columns of these datasets: ",df.columns)
# Out:
# The Dimension of these datasets:  (158, 12)
# The alll columns of these datasets:  Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
# Checking the data type of columns
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
# Now Checking the unll values are presents on not in these datasets
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [raw]
# There is no null vlaues presents in these datasets.

# %%
# Lets check null vlaues using Heat map
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [raw]
# Here is also see that no null values are presents

# %%
# Count values of each columns
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
#
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
#
#
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# ...

# %%
# Now separating hte categorical columns and numerical columns
# Checking for categorical Coumns
categorical_col = []
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print("Categorical Columns: ",categorical_col)
print("\n")

# Checking for numerical columns
numerical_col = []
for i  in df.dtypes.index:
    if df.dtypes[i]!= "object":
        numerical_col.append(i)
print("Numerical Columns: ",numerical_col)
# Out:
# Categorical Columns:  ['Country', 'Region']
#
#
# Numerical Columns:  ['Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
# Checking number of unique values in ech column
df.nunique().to_frame("No. of unique values")
# Out:
#                                No. of unique values
# Country                                         158
# Region                                           10
# Happiness Rank                                  157
# Happiness Score                                 157
# Standard Error                                  153
# Economy (GDP per Capita)                        158
# Family                                          158
# Health (Life Expectancy)                        157
# Freedom                                         158
# Trust (Government Corruption)                   157
# Generosity                                      158
# Dystopia Residual                               158

# %%
df['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %% [markdown]
# # Visualize the data

# %%
# visualize the number of  people survived
ax=sns.countplot(x='Region',data=df)
print(df['Region'].value_counts())
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# # Data Distributed

# %%
plotnumber = 1  # Initialize subplot number
for col in numerical_col:
    if plotnumber <= 10:  # Ensure plotnumber is within valid range (1 to 4 for a 2x2 grid)
        ax = plt.subplot(5,5, plotnumber)
        sns.distplot(df[col], color="m")
        plt.xlabel(col, fontsize=12)
        plotnumber += 1  # Increment plotnumber for the next subplot
    else:
        break  # Exit loop if plotnumber exceeds the maximum number of subplots

plt.tight_layout()  # Adjust subplot layout to prevent overlap
plt.show()  # Display the figure with subplots

# %% [markdown]
# # Relational Analysis

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Happiness Rank', y='Region', data=df)
plt.xticks(rotation=90)  # Rotate x-axis labels if needed
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Happiness Score', y='Region', hue='Region', data=df)
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df,hue="Region",palette="Dark2")
plt.show()

# %% [markdown]
# # Checking for outliers

# %%
# Now we check the data have outliers or not
num_numerical_cols = len(numerical_col)
num_rows = 5  # Number of rows in the subplot grid
num_cols = 4  # Number of columns in the subplot grid
total_subplots = num_rows * num_cols

# Create a new figure and set its size
plt.figure(figsize=(20, 16), facecolor="white")  # Adjust the figure size as needed

# Iterate over numerical columns and create subplots for boxplots
plotnumber = 1
for col in numerical_col:
    if plotnumber <= total_subplots:
        # Create subplot at the specified position
        ax = plt.subplot(num_rows, num_cols, plotnumber)
        
        # Plot boxplot for the current column using seaborn
        sns.boxplot(x=df[col], palette="Set2_r", ax=ax)
        
        # Customize subplot labels and ticks
        plt.xlabel(col, fontsize=15)
        plt.ylabel("")  # Clear y-axis label
        plt.xticks(rotation=0, fontsize=10)
        plt.yticks(fontsize=10)
        
        plotnumber += 1  # Increment plotnumber for the next subplot

# Adjust layout to prevent overlap and improve readability
plt.tight_layout()
plt.show()  # Display the figure with subplots

# %% [raw]
# Here we can see that some columns has contailns outliers now we removed outliers using IQR method

# %% [markdown]
# # Using IQR Method to Removed the extra outliers

# %%
import pandas as pd

# Assuming df is your DataFrame containing the relevant columns

# Calculate IQR
columns_of_interest = ['Standard Error', 'Family', 'Trust (Government Corruption)','Generosity','Dystopia Residual']
Q1 = df[columns_of_interest].quantile(0.25)
Q3 = df[columns_of_interest].quantile(0.75)
IQR = Q3 - Q1

# Determine outliers based on IQR
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[((df[columns_of_interest] < lower_bound) | (df[columns_of_interest] > upper_bound)).any(axis=1)]

# Remove outliers
df1 = df[~((df[columns_of_interest] < lower_bound) | (df[columns_of_interest] > upper_bound)).any(axis=1)]

# Print cleaned DataFrame
print("DataFrame after removing outliers:")
print(df1)

# Optional: Print removed outliers
print("\nOutliers removed:")
print(outliers)
# Out:
# DataFrame after removing outliers:
#           Country                           Region  Happiness Rank  \
# 1         Iceland                   Western Europe               2
# 4          Canada                    North America               5
# 6     Netherlands                   Western Europe               7
# 9       Australia        Australia and New Zealand              10
# 10         Israel  Middle East and Northern Africa              11
# ..            ...                              ...             ...
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 154         Benin               Sub-Saharan Africa             155
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# ...

# %%
num_numerical_cols = len(numerical_col)
num_rows = 5  # Number of rows in the subplot grid
num_cols = 4  # Number of columns in the subplot grid
total_subplots = num_rows * num_cols

# Create a new figure and set its size
plt.figure(figsize=(20, 16), facecolor="white")  # Adjust the figure size as needed

# Iterate over numerical columns and create subplots for boxplots
plotnumber = 1
for col in numerical_col:
    if plotnumber <= total_subplots:
        # Create subplot at the specified position
        ax = plt.subplot(num_rows, num_cols, plotnumber)
        
        # Plot boxplot for the current column using seaborn
        sns.boxplot(x=df1[col], palette="Set2_r", ax=ax)
        
        # Customize subplot labels and ticks
        plt.xlabel(col, fontsize=15)
        plt.ylabel("")  # Clear y-axis label
        plt.xticks(rotation=0, fontsize=10)
        plt.yticks(fontsize=10)
        
        plotnumber += 1  # Increment plotnumber for the next subplot

# Adjust layout to prevent overlap and improve readability
plt.tight_layout()
plt.show()  # Display the figure with subplots

# %%
import pandas as pd

# Assuming df is your DataFrame containing the relevant columns

# Calculate IQR
columns_of_interest = ['Standard Error', 'Trust (Government Corruption)','Generosity','Dystopia Residual']
Q1 = df[columns_of_interest].quantile(0.25)
Q3 = df[columns_of_interest].quantile(0.75)
IQR = Q3 - Q1

# Determine outliers based on IQR
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[((df[columns_of_interest] < lower_bound) | (df[columns_of_interest] > upper_bound)).any(axis=1)]

# Remove outliers
df1 = df[~((df[columns_of_interest] < lower_bound) | (df[columns_of_interest] > upper_bound)).any(axis=1)]

# Print cleaned DataFrame
print("DataFrame after removing outliers:")
print(df1)

# Optional: Print removed outliers
print("\nOutliers removed:")
print(outliers)
# Out:
# DataFrame after removing outliers:
#           Country                           Region  Happiness Rank  \
# 1         Iceland                   Western Europe               2
# 4          Canada                    North America               5
# 6     Netherlands                   Western Europe               7
# 9       Australia        Australia and New Zealand              10
# 10         Israel  Middle East and Northern Africa              11
# ..            ...                              ...             ...
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 154         Benin               Sub-Saharan Africa             155
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# ...

# %% [raw]
# After doing this code run several times, its outliers were removed to some extent.

# %%
num_numerical_cols = len(numerical_col)
num_rows = 5  # Number of rows in the subplot grid
num_cols = 4  # Number of columns in the subplot grid
total_subplots = num_rows * num_cols

# Create a new figure and set its size
plt.figure(figsize=(20, 16), facecolor="white")  # Adjust the figure size as needed

# Iterate over numerical columns and create subplots for boxplots
plotnumber = 1
for col in numerical_col:
    if plotnumber <= total_subplots:
        # Create subplot at the specified position
        ax = plt.subplot(num_rows, num_cols, plotnumber)
        
        # Plot boxplot for the current column using seaborn
        sns.boxplot(x=df1[col], palette="Set2_r", ax=ax)
        
        # Customize subplot labels and ticks
        plt.xlabel(col, fontsize=15)
        plt.ylabel("")  # Clear y-axis label
        plt.xticks(rotation=0, fontsize=10)
        plt.yticks(fontsize=10)
        
        plotnumber += 1  # Increment plotnumber for the next subplot

# Adjust layout to prevent overlap and improve readability
plt.tight_layout()
plt.show()  # Display the figure with subplots

# %% [raw]
# At last so many outlier removed succefully

# %% [markdown]
# # Now Checking For Skewness

# %%
# Encoding categorical columns using OrdinalEnocoder
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df1.columns:
    if df1[i].dtypes =="object":
        df1[i]=OE.fit_transform(df1[i].values.reshape(-1,1))
df1
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 1       52.0     9.0               2            7.561         0.04884
# 4       23.0     5.0               5            7.427         0.03553
# 6       85.0     9.0               7            7.378         0.02799
# 9        6.0     0.0              10            7.284         0.04083
# 10      58.0     4.0              11            7.278         0.03470
# ..       ...     ...             ...              ...             ...
# 150     60.0     8.0             151            3.655         0.05141
# 151     20.0     8.0             152            3.587         0.04324
# 152      0.0     7.0             153            3.575         0.03084
# 154     13.0     8.0             155            3.340         0.03656
# 157    114.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# Now all columns convert into numerical columns

# %%
# Now all data are converted into numercial form so no we check skewness
df1.skew()
# Out:
# Country                          0.000000
# Region                          -0.018371
# Happiness Rank                  -0.023892
# Happiness Score                  0.153024
# Standard Error                   0.459383
# Economy (GDP per Capita)        -0.388032
# Family                          -1.055883
# Health (Life Expectancy)        -0.710103
# Freedom                         -0.377460
# Trust (Government Corruption)    1.108548
# Generosity                       0.675357
# Dystopia Residual                0.164524
# dtype: float64

# %%
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %% [raw]
# Now we see all skewness are looks like perfect. Its mean no need to change .

# %% [raw]
# Now dropping the uniques columns at these datasets

# %%
# dropping the name and ticket columns
df1.drop(['Country'], axis=1, inplace=True)

# %%
# Separating the independent and target varaible into x and y
x = df1.drop(['Happiness Score'], axis=1)  # Features we remove price columns
y = df1['Happiness Score']    #  Here now the price is my target variable
print("Feature Dimensions= ",x.shape)
print("Label Dimensions",y.shape)
# Out:
# Feature Dimensions=  (129, 10)
# Label Dimensions (129,)

# %% [raw]
# Now find the best model to fit these datasets

# %% [markdown]
# # Find the best model

# %%
# importing all necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.svm import SVR
from sklearn.ensemble import ExtraTreesRegressor

# %%
# Finding the best random state
maxAccu = 0
maxRS = 0
for i in range(1, 200):
    # Splitting the data into train and test sets using current random state (i)
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.30, random_state=i)
    
    # Initializing and training the Gradient Boosting Regressor
    RFR = RandomForestRegressor()
    RFR.fit(x_train, y_train)
    pred = RFR.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print("Maximum r2 score is ",maxAccu,"on Random_State",maxRS)
# Out:
# Maximum r2 score is  0.998749509085437 on Random_State 168

# %% [markdown]
# # Best accuracy and random state

# %%
print("Best accuracy is", maxAccu, "at random_state", maxRS)
# Out:
# Best accuracy is 0.998749509085437 at random_state 168

# %% [raw]
# Here is the accuracy is 100 % and random state is 168

# %% [markdown]
# # Creating train test split

# %%
# Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=168)

# %% [raw]
# Now cheking one by one all Regression models

# %% [markdown]
# # LinearRegression

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR = LR.predict(x_test)
pred_train= LR.predict(x_train)
print(LR)
print("R2_Score: ",r2_score(y_test,pred_LR))
print("R2_Score on training Data: ",r2_score(y_train,pred_train)*100)
print("Mean Absolute error:-",mean_absolute_error(y_test,pred_LR))
print("Mean Squared error:-",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# LinearRegression()
# R2_Score:  0.9999998727913039
# R2_Score on training Data:  99.99999439751288
# Mean Absolute error:- 0.00029361327522752054
# Mean Squared error:- 1.1024714876816873e-07
# Root Mean Squared Error:- 0.00033203486077243265

# %%
#Plotting
plt.figure(figsize = (10,6))
plt.scatter(x= pred_LR,y=y_test,color="r")
plt.plot(pred_LR,pred_LR,color = "b")
plt.xlabel("Actual",fontsize = 14)
plt.ylabel("Predicted",fontsize= 14)
plt.title("Linear Regression ",fontsize = 18 )
plt.show()

# %% [markdown]
# # RandomForestRegressor

# %%
RFR = RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR = RFR.predict(x_test)
pred_train= RFR.predict(x_train)

print("R2_Score: ",r2_score(y_test,pred_RFR))
print("R2_Score on training Data: ",r2_score(y_train,pred_train)*100)
print("Mean Absolute error:-",mean_absolute_error(y_test,pred_RFR))
print("Mean Squared error:-",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_Score:  0.9985068382730359
# R2_Score on training Data:  99.90194740095222
# Mean Absolute error:- 0.026837948717948715
# Mean Squared error:- 0.0012940689435897823
# Root Mean Squared Error:- 0.035973169774010494

# %% [markdown]
# # KNN

# %%
knn = KNN()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
pred_train= knn.predict(x_train)

print("R2_Score: ",r2_score(y_test,pred_knn))
print("R2_Score on training Data: ",r2_score(y_train,pred_train)*100)
print("Mean Absolute error:-",mean_absolute_error(y_test,pred_knn))
print("Mean Squared error:-",mean_squared_error(y_test,pred_knn))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2_Score:  0.9957383128161849
# R2_Score on training Data:  99.50831605587646
# Mean Absolute error:- 0.04297948717948733
# Mean Squared error:- 0.0036934492307692337
# Root Mean Squared Error:- 0.060773754456749124

# %% [markdown]
# # GradientBoostingRegressor

# %%
GBR = GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR = GBR.predict(x_test)
pred_train= GBR.predict(x_train)

print("R2_Score: ",r2_score(y_test,pred_GBR))
print("R2_Score on training Data: ",r2_score(y_train,pred_train)*100)
print("Mean Absolute error:-",mean_absolute_error(y_test,pred_GBR))
print("Mean Squared error:-",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2_Score:  0.9984388727313913
# R2_Score on training Data:  99.99994886055843
# Mean Absolute error:- 0.026648729187041826
# Mean Squared error:- 0.001352972205767026
# Root Mean Squared Error:- 0.0367827705015137

# %% [markdown]
# # Lasso

# %%
lasso = Lasso()
lasso.fit(x_train,y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)

print("R2_Score: ",r2_score(y_test,pred_lasso))
print("R2_Score on training Data: ",r2_score(y_train,pred_train)*100)
print("Mean Absolute error:-",mean_absolute_error(y_test,pred_lasso))
print("Mean Squared error:-",mean_squared_error(y_test,pred_lasso))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_Score:  0.9858589062489933
# R2_Score on training Data:  98.52781848092613
# Mean Absolute error:- 0.0921160753936498
# Mean Squared error:- 0.012255571463631973
# Root Mean Squared Error:- 0.1107048845518208

# %% [markdown]
# # Ridge

# %%
rd = Ridge()
rd.fit(x_train,y_train)
pred_ridge = rd.predict(x_test)
pred_train = rd.predict(x_train)

print("R2_Score: ",r2_score(y_test,pred_ridge))
print("R2_Score on training Data: ",r2_score(y_train,pred_train)*100)
print("Mean Absolute error:-",mean_absolute_error(y_test,pred_ridge))
print("Mean Squared error:-",mean_squared_error(y_test,pred_ridge))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_ridge)))
# Out:
# R2_Score:  0.988135133167249
# R2_Score on training Data:  99.16742421179634
# Mean Absolute error:- 0.08322273812450207
# Mean Squared error:- 0.010282848408731107
# Root Mean Squared Error:- 0.10140438061903986

# %% [markdown]
# # DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr = dtr.predict(x_test)
pred_train = dtr.predict(x_train)

print("R2_Score: ",r2_score(y_test,pred_dtr))
print("R2_Score on training Data: ",r2_score(y_train,pred_train)*100)
print("Mean Absolute error:-",mean_absolute_error(y_test,pred_dtr))
print("Mean Squared error:-",mean_squared_error(y_test,pred_dtr))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_Score:  0.9937186761244271
# R2_Score on training Data:  100.0
# Mean Absolute error:- 0.053846153846153794
# Mean Squared error:- 0.005443794871794864
# Root Mean Squared Error:- 0.07378207690079525

# %% [markdown]
# # SVR

# %%
svr = SVR()
svr.fit(x_train,y_train)
pred_svr = svr.predict(x_test)
pred_train = svr.predict(x_train)

print("R2_Score: ",r2_score(y_test,pred_svr))
print("R2_Score on training Data: ",r2_score(y_train,pred_train)*100)
print("Mean Absolute error:-",mean_absolute_error(y_test,pred_svr))
print("Mean Squared error:-",mean_squared_error(y_test,pred_svr))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2_Score:  0.9906467892819337
# R2_Score on training Data:  98.86374579206544
# Mean Absolute error:- 0.07789206002205946
# Mean Squared error:- 0.008106087434821586
# Root Mean Squared Error:- 0.09003381273067128

# %% [markdown]
# # ExtraTreesRegressor

# %%
etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr = etr.predict(x_test)
pred_train = etr.predict(x_train)

print("R2_Score: ",r2_score(y_test,pred_etr))
print("R2_Score on training Data: ",r2_score(y_train,pred_train)*100)
print("Mean Absolute error:-",mean_absolute_error(y_test,pred_etr))
print("Mean Squared error:-",mean_squared_error(y_test,pred_etr))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2_Score:  0.9975645091350276
# R2_Score on training Data:  100.0
# Mean Absolute error:- 0.03480974358974327
# Mean Squared error:- 0.0021107513230768913
# Root Mean Squared Error:- 0.0459429137416957

# %% [raw]
# Now we observed is my Linear Regression model is best becuase is accuracy is above 100%

# %% [raw]
# In linear regression htere is no hyper parametrs presents so that why we solve the direct

# %% [markdown]
# # Now Final model

# %%
LR.fit(x_train,y_train)
pred = LR.predict(x_test)
print("R2_Score: ",r2_score(y_test,pred))
print("R2_Score on training Data: ",r2_score(y_train,pred_train)*100)
print("Mean Absolute error:-",mean_absolute_error(y_test,pred))
print("Mean Squared error:-",mean_squared_error(y_test,pred))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_Score:  0.9999998727913039
# R2_Score on training Data:  100.0
# Mean Absolute error:- 0.00029361327522752054
# Mean Squared error:- 1.1024714876816873e-07
# Root Mean Squared Error:- 0.00033203486077243265

# %% [markdown]
# # Saving the best model

# %%
# Saving the model
import joblib
joblib.dump(LR,"Happiness_score.pkl")
# Out:
# ['Happiness_score.pkl']

# %%
import pickle
filename = "Happiness_score.pkl"
pickle.dump(LR, open(filename,'wb'))  #Saved model

# %% [markdown]
# # Predicting the saved model

# %%
load_model = pickle.load(open("Happiness_score.pkl",'rb'))
result = load_model.score(x_test,y_test)
print(result*100)
# Out:
# 99.99998727913038

# %% [raw]
# Here we can see that its my final accuracy which is approximate 100%

# %% [markdown]
# # Conclusion

# %%
conclusion = pd.DataFrame([load_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion
# Out:
#                  0         1         2         3         4         5   \
# Predicted  5.770428  7.283928  5.192327  6.302423  5.758603  3.903659
# Original   5.770000  7.284000  5.192000  6.302000  5.759000  3.904000
#
#                  6         7         8         9   ...        29        30  \
# Predicted  3.574365  6.130278  5.193618  5.812551  ...  4.787938  4.517786
# Original   3.575000  6.130000  5.194000  5.813000  ...  4.788000  4.518000
#
#                  31        32        33        34        35        36  \
# Predicted  5.995228  4.507277  4.349889  5.695255  5.688674  3.680722
# Original   5.995000  4.507000  4.350000  5.695000  5.689000  3.681000
#
#                  37        38
# Predicted  4.839128  4.685424
# Original   4.839000  4.686000
#
# [2 rows x 39 columns]

# %%
# We use these data to predict the happiness score
x
# Out:
#      Region  Happiness Rank  Standard Error  Economy (GDP per Capita)  \
# 1       9.0               2         0.04884                   1.30232
# 4       5.0               5         0.03553                   1.32629
# 6       9.0               7         0.02799                   1.32944
# 9       0.0              10         0.04083                   1.33358
# 10      4.0              11         0.03470                   1.22857
# ..      ...             ...             ...                       ...
# 150     8.0             151         0.05141                   0.46534
# 151     8.0             152         0.04324                   0.25812
# 152     7.0             153         0.03084                   0.31982
# 154     8.0             155         0.03656                   0.28665
# 157     8.0             158         0.06727                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom  \
# 1    1.40223                   0.94784  0.62877
# ...

# %% [markdown]
# # Making the diagram of predicted happiness score

# %%
import numpy as np

# Define input data (Happiness  Datasets)

input_data = np.array([[9.0,2,0.04884,1.30232,1.40223,0.94784,0.62877,0.14145,0.43630,2.70201]])  # Example input data (single sample)

# Make prediction using the trained SVR model
prediction = LR.predict(input_data)  # Use 'svr' for prediction
print("Input Data:", input_data)
print("The predicted Happiness Score is :", prediction)
# Out:
# Input Data: [[9.      2.      0.04884 1.30232 1.40223 0.94784 0.62877 0.14145 0.4363
#   2.70201]]
# The predicted Happiness Score is : [7.56085744]

# %% [markdown]
# # THANK YOU
